# %%
import pandas as pd
import matplotlib.pyplot as plt

# Visualisasi Bubble Plot (Jawaban Pertanyaan #1)
# X = WorkExp, Y = TimeSearching, Size = Age
plt.figure(figsize=(12, 8))
plt.scatter(df['WorkExp'], 
            df['TimeSearching'], 
            s=df['Age_Numeric'] * 2, # Ukuran gelembung berdasarkan Umur
            alpha=0.4, 
            c='orange', 
            edgecolors='black')

plt.title('Bubble Plot: WorkExp vs TimeSearching (Ukuran = Umur)')
plt.xlabel('WorkExp (Pengalaman Kerja)')
plt.ylabel('TimeSearching (Waktu Mencari Solusi)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       4 # Visualisasi Bubble Plot (Jawaban Pertanyaan #1)
#       5 # X = WorkExp, Y = TimeSearching, Size = Age
#       6 plt.figure(figsize=(12, 8))
# ----> 7 plt.scatter(df['WorkExp'],
#       8             df['TimeSearching'],
#       9             s=df['Age_Numeric'] * 2, # Ukuran gelembung berdasarkan Umur
#      10             alpha=0.4,
#      11             c='orange',
#      12             edgecolors='black')
#      14 plt.title('Bubble Plot: WorkExp vs TimeSearching (Ukuran = Umur)')
#      15 plt.xlabel('WorkExp (Pengalaman Kerja)')
#
# NameError: name 'df' is not defined
