# %%
import pandas as pd
import matplotlib.pyplot as plt

# Membersihkan data Age (karena di dataset baru biasanya berupa string '25-34 years old')
df['Age_Numeric'] = df['Age'].str.extract('(\d+)').astype(float)

# Visualisasi Scatter Plot (Jawaban Pertanyaan #3)
# Menggunakan Age vs WorkExp (sebagai pengganti WorkWeekHrs)
plt.figure(figsize=(10, 6))
plt.scatter(df['Age_Numeric'], df['WorkExp'], alpha=0.5, color='blue')

plt.title('Scatter Plot: Umur vs Pengalaman Kerja (WorkExp)')
plt.xlabel('Age (Umur)')
plt.ylabel('WorkExp (Tahun Pengalaman)')
plt.show()
